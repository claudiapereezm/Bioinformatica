# %% [markdown]
# # PRIMER CARACTER

# %% [markdown]
# #### De una lista de palabras, cuenta el número de palabras que tengas un número de letras que sea múltiplo de 3.

# %%
lista_palabras = ["navidad", "otoño","roble","setas","campo","ciervo","nueces","calabazas","perdices","bellotas","frio","hoguera","brujas","ocre","corteza","musgo"]

# %%
palabras_mult3 = [palabra for palabra in lista_palabras if len(palabra) % 3 == 0]
print("Las palabras con longitud múltiplo de 3 son:", palabras_mult3)
print("El número total de palabras sería:", len(palabras_mult3))
# Out:
# Las palabras con longitud múltiplo de 3 son: ['ciervo', 'nueces', 'calabazas', 'brujas']
# El número total de palabras sería: 4

# %% [markdown]
# # SEGUNDO CARACTER

# %% [markdown]
# #### Cuánto da una ecuación en la que primero se sumen 5 y 7, luego a eso se le hace la raíz cuadrada y posteriormente se eleva al cuadrado? Por último, se divide todo entre 3.

# %%
import math
resultado = (math.sqrt(5 + 7) ** 2) / 3
print(resultado)
# Out:
# 3.9999999999999996

# %% [markdown]
# # TERCER CARACTER

# %% [markdown]
# #### Calcula el área de un círculo de radio 3 y después divídela entre 9.

# %%
pi = 3.14
radio = 3

# %%
area = pi * radio**2
resultado = area / 9
print("El área del círculo es:",resultado)
# Out:
# El área del círculo es: 3.14

# %% [markdown]
# # CUARTO Y QUINTO CARACTER

# %% [markdown]
# #### Cuenta todas las vocales de esta frase

# %%
frase = "Estoy un poco estresada porque se me va a explotar la bomba"

vocales = "aeiou"
conteo = {v: sum(1 for ch in frase.lower() if ch == v) for v in vocales}
total = sum(conteo.values())

print(conteo)
print("El total de vocales en la frase es:", total)
# Out:
# {'a': 7, 'e': 7, 'i': 0, 'o': 6, 'u': 2}
# El total de vocales en la frase es: 22

# %% [markdown]
# # SEXTO CARACTER

# %% [markdown]
# #### De la siguiente frase saca la primera letra de la primera palabra que sea un palíndromo.

# %%
frase_palindromo = "Vaya Parece Que Somos Un Poco Kamikazes Pero Ya Casi Esta"

palabras = frase_palindromo.split()

for palabra in palabras:
    p = palabra.lower()
    if p == p[::-1]:
        print("La primera palabra palíndroma es:", palabra)
        print("Su primera letra es:", palabra[0])
        break
# Out:
# La primera palabra palíndroma es: Somos
# Su primera letra es: S

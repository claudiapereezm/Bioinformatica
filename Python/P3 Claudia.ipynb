# %% [markdown]
# # Claudia Pérez, María Vargas, Uxía Lamelas y Alfonso Borbón

# %% [markdown]
# # PRACTICA 3
#
#
# ## JUEGO DE ADIVINANZAS
#
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %% [markdown]
# ##### PISTAS
# 1. Trata obtener un número aleatorio entre el 1 y el 100
# 2. Haz una introducción de tu juego y explica las reglas
# 3. Crea una lista que almacene los intentos.
# 4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
# 5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
import random

print("¡Bienvenido al juego de adivinanzas!")
print("He pensado un número del 1 al 100 y tienes que adivinar cuál es...")
print("Reglas:")
print("- Si tu número está fuera del rango 1–100, te diré 'FUERA DE LÍMITES'.")
print("- En el primer intento:")
print("    · Si estás a menos de 10 de distancia -> ¡CALIENTE!")
print("    · Si estás a 10 o más -> ¡FRÍO!")
print("- En los intentos siguientes:")
print("    · Si te acercas más que antes -> ¡MÁS CALIENTE!")
print("    · Si te alejas -> ¡MÁS FRÍO!")
print("- Gana quien acierte el número. Suerte!\n")

# Número aleatorio secreto
numero_secreto = random.randint(1, 100)

# Lista para almacenar intentos
intentos = []

while True:
    # Pedir número al jugador
    intento = input("Introduce un número entre 1 y 100: ")
    
    # Verificar que es un entero válido
    if not intento.isdigit():
        print("Por favor introduce un número válido.")
        continue
    
    intento = int(intento)
    
    # Verificar límites
    if intento < 1 or intento > 100:
        print("FUERA DE LÍMITES")
        continue
    
    # Añadir intento a la lista
    intentos.append(intento)
    
    # Comprobación de acierto
    if intento == numero_secreto:
        print(f"¡Has acertado...VIVA ESPAÑAAA!! El número era {numero_secreto}.")
        print(f"Te ha llevado {len(intentos)} intentos.")
        break
    
    # Si es el primer intento, damos pista básica
    if len(intentos) == 1:
        if abs(numero_secreto - intento) <= 10:
            print("¡CALIENTE!")
        else:
            print("¡FRÍO!")
    else:
        # Comparar con intento anterior
        if abs(numero_secreto - intentos[-1]) < abs(numero_secreto - intentos[-2]):
            print("¡MÁS CALIENTE!")
        else:
            print("¡MÁS FRÍO!")
# Out:
# ¡Bienvenido al juego de adivinanzas!
# He pensado un número del 1 al 100 y tienes que adivinar cuál es...
# Reglas:
# - Si tu número está fuera del rango 1–100, te diré 'FUERA DE LÍMITES'.
# - En el primer intento:
#     · Si estás a menos de 10 de distancia -> ¡CALIENTE!
#     · Si estás a 10 o más -> ¡FRÍO!
# - En los intentos siguientes:
#     · Si te acercas más que antes -> ¡MÁS CALIENTE!
#     · Si te alejas -> ¡MÁS FRÍO!
# - Gana quien acierte el número. Suerte!
# Introduce un número entre 1 y 100:  2
# ¡FRÍO!
# Introduce un número entre 1 y 100:  50
# ¡MÁS FRÍO!
# Introduce un número entre 1 y 100:  20
# ¡MÁS CALIENTE!
# Introduce un número entre 1 y 100:  25
# ¡MÁS FRÍO!
# Introduce un número entre 1 y 100:  18
# ¡MÁS CALIENTE!
# Introduce un número entre 1 y 100:  19
# ¡MÁS CALIENTE!
# Introduce un número entre 1 y 100:  16
# ¡MÁS FRÍO!
# Introduce un número entre 1 y 100:  22
# ¡MÁS CALIENTE!
# Introduce un número entre 1 y 100:  21
# ¡Has acertado...VIVA ESPAÑAAA!! El número era 21.
# Te ha llevado 9 intentos.
